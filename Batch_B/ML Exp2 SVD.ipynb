# %% [markdown]
# <a href="https://colab.research.google.com/github/KedaarK/ML-Experiments-D17A/blob/main/Batch_B/ML%20Exp2%20SVD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Singular-value decomposition SVD**

# %% [markdown]
# #Definition of Singular Values
#
# Singular values are the non-negative values on the diagonal of the
# Σ
# Σ matrix obtained from the Singular Value Decomposition (SVD) of a matrix. They indicate the magnitude or importance of the corresponding singular vectors in representing the original matrix.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
from scipy.linalg import svd

# %% [markdown]
# Define a matrix

# %%
# Define a 3x2 matrix
A = np.array([[1, 2],
              [3, 4],
              [5, 6]])

print("Original matrix A:")
print(A)
# Out:
# Original matrix A:
# [[1 2]
#  [3 4]
#  [5 6]]

# %% [markdown]
# Calculate SVD

# %%
# Perform SVD
U, s, VT = svd(A)

print("\nMatrix U (left singular vectors):")
print(U)

print("\nSingular values (vector s):")
print(s)

print("\nMatrix VT (right singular vectors transposed):")
print(VT)
# Out:
# Matrix U (left singular vectors):
# [[-0.2298477   0.88346102  0.40824829]
#  [-0.52474482  0.24078249 -0.81649658]
#  [-0.81964194 -0.40189603  0.40824829]]
#
# Singular values (vector s):
# [9.52551809 0.51430058]
#
# Matrix VT (right singular vectors transposed):
# [[-0.61962948 -0.78489445]
#  [-0.78489445  0.61962948]]
#
# Diagonal matrix Sigma from singular values:
# [[9.52551809 0.        ]
#  [0.         0.51430058]
#  [0.         0.        ]]
#
# Reconstructed matrix (U * Sigma * VT):
# [[1. 2.]
#  [3. 4.]
#  [5. 6.]]

# %%
# If you want to convert singular values vector s into a diagonal matrix Sigma:
Sigma = np.zeros((A.shape[0], A.shape[1]))
np.fill_diagonal(Sigma, s)

print("\nDiagonal matrix Sigma from singular values:")
print(Sigma)

# Verify reconstruction
A_reconstructed = U @ Sigma @ VT
print("\nReconstructed matrix (U * Sigma * VT):")
print(A_reconstructed)
# Out:
# Diagonal matrix Sigma from singular values:
# [[9.52551809 0.        ]
#  [0.         0.51430058]
#  [0.         0.        ]]
#
# Reconstructed matrix (U * Sigma * VT):
# [[1. 2.]
#  [3. 4.]
#  [5. 6.]]

# %% [markdown]
# ##Image Compression usiing SVD

# %% [markdown]
# When k value is 50 (Normal)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Replace 'your_image.jpg' with the actual file name you uploaded
image_path = 'image.jpg'

# Load image and convert to grayscale
img = Image.open(image_path).convert('L')
img_matrix = np.array(img)

print(f"Original image shape: {img_matrix.shape}")

# Perform SVD
U, S, VT = np.linalg.svd(img_matrix, full_matrices=False)

# Function to reconstruct image using k singular values
def compress_image(U, S, VT, k):
    S_k = np.diag(S[:k])
    U_k = U[:, :k]
    VT_k = VT[:k, :]
    return np.dot(U_k, np.dot(S_k, VT_k))

# Choose number of singular values to keep (adjust for compression level)
k = 50

# Reconstruct compressed image
img_compressed = compress_image(U, S, VT, k)

# Plot original and compressed images
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title('Original Grayscale Image')
plt.imshow(img_matrix, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title(f'Compressed Image with k={k} singular values')
plt.imshow(img_compressed, cmap='gray')
plt.axis('off')

plt.show()
# Out:
# Original image shape: (3770, 5306)

# %% [markdown]
# When k value is 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Replace 'your_image.jpg' with the actual file name you uploaded
image_path = 'image.jpg'

# Load image and convert to grayscale
img = Image.open(image_path).convert('L')
img_matrix = np.array(img)

print(f"Original image shape: {img_matrix.shape}")

# Perform SVD
U, S, VT = np.linalg.svd(img_matrix, full_matrices=False)

# Function to reconstruct image using k singular values
def compress_image(U, S, VT, k):
    S_k = np.diag(S[:k])
    U_k = U[:, :k]
    VT_k = VT[:k, :]
    return np.dot(U_k, np.dot(S_k, VT_k))

# Choose number of singular values to keep (adjust for compression level)
k = 1

# Reconstruct compressed image
img_compressed = compress_image(U, S, VT, k)

# Plot original and compressed images
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title('Original Grayscale Image')
plt.imshow(img_matrix, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title(f'Compressed Image with k={k} singular values')
plt.imshow(img_compressed, cmap='gray')
plt.axis('off')

plt.show()
# Out:
# Original image shape: (3770, 5306)

# %% [markdown]
# When k value is 5000

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Replace 'your_image.jpg' with the actual file name you uploaded
image_path = 'image.jpg'

# Load image and convert to grayscale
img = Image.open(image_path).convert('L')
img_matrix = np.array(img)

print(f"Original image shape: {img_matrix.shape}")

# Perform SVD
U, S, VT = np.linalg.svd(img_matrix, full_matrices=False)

# Function to reconstruct image using k singular values
def compress_image(U, S, VT, k):
    S_k = np.diag(S[:k])
    U_k = U[:, :k]
    VT_k = VT[:k, :]
    return np.dot(U_k, np.dot(S_k, VT_k))

# Choose number of singular values to keep (adjust for compression level)
k = 5000

# Reconstruct compressed image
img_compressed = compress_image(U, S, VT, k)

# Plot original and compressed images
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title('Original Grayscale Image')
plt.imshow(img_matrix, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title(f'Compressed Image with k={k} singular values')
plt.imshow(img_compressed, cmap='gray')
plt.axis('off')

plt.show()
# Out:
# Original image shape: (3770, 5306)
